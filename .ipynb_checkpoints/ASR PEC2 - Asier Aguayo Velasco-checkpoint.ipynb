# %% [markdown]
# <h2>Tweets relevantes sobre la final de la Uefa Europa League</h2>

# %%
#Importación de 

from twython import Twython
import numpy as np
import pandas as pd
import time

# %%
APP_KEY = '4TnmlDlA8IGcXygNFa0JrufkL'
APP_SECRET = 'da6eZKBS4LFy3oWsGMr3V8Kt3dmvehAQBVW99w7P37oGTl4KbD'
OAUTH_TOKEN = '376631666-HnhBhFaSoJdpGFbB7q0BLN9nOJV92niFaDl9Sa0l'  # Access Token here
OAUTH_TOKEN_SECRET = 'aIQf3ovWhCQ6fw6undzkq7FpU82y8cMzhmz7m5mVDZKfd'  # Access Token Secret here

# %%
twitter = Twython(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
auth = twitter.get_authentication_tokens()

# %%
columns = ['tweetID', 'text', 'replyTo', 'retweeted', 'tweetDate', 'userID', 'userName', 'friends', 'followers', 'location']

rows = []
last_id = 0
tweetCount = 0
df = pd.DataFrame()
result = twitter.search(q='#EuropaLeagueFinal2019', result_type='popular', count=100)
for tweet in result['statuses']:
        tweetData = {
            'tweetID' : tweet['id'],
            'text' : tweet['text'],
            'replyTo' : tweet['in_reply_to_user_id'],
            'retweeted' : tweet['retweet_count'],
            'tweetDate' : tweet['created_at'],
            'userID' : tweet['user']['id'],
            'userName' : tweet['user']['name'],
            'friends' : tweet['user']['friends_count'],
            'followers' : tweet['user']['followers_count'],
            'location' : tweet['user']['location']
        }
        rows.append(tweetData)

result = twitter.search(q='#EuropaLeagueFinal2019', count=100)
while (tweetCount < 1000):
    for tweet in result['statuses']:
        dictionaryColValue = {
            'tweetID' : tweet['id'],
            'text' : tweet['text'],
            'replyTo' : tweet['in_reply_to_user_id'],
            'retweeted' : tweet['retweet_count'],
            'tweetDate' : tweet['created_at'],
            'userID' : tweet['user']['id'],
            'userName' : tweet['user']['name'],
            'followers' : tweet['user']['followers_count'],
            'location' : tweet['user']['location']
        }
        rows.append(dictionaryColValue)
        tweetCount += 1
        
    last_id = rows[-1]['tweetID']
    #last_id = result['search_metadata']['max_id']
    result = twitter.search(q='#EuropaLeagueFinal2019', count=100, max_id = last_id)
        
df = pd.DataFrame(rows, columns=columns)
df = df.set_index('tweetID') 
df = df.sort_values(by=['tweetID'])
df
# Out:
#                                                                   text  \
# tweetID
# 1133434683801427968  Chelsea midfielder N’Golo Kanté in deep discus...
# 1133644142003671042  ⚽ Qui sera le 1er buteur du match Chelsea - Ar...
# 1133701370253643776  Ok big bollocks @Beno_ldn you called this on, ...
# 1133702237870526464  Coming up @BBCNews @BBCOne we’re live from Bak...
# 1133795141129523201  N'Golo Kante is passed fit, Antonio Rudiger, R...
# 1133795344297467906  Petr Cech is in goal for Arsenal... in the fin...
# 1133812827540676610  How far away is the camera? 😂\n#EuropaLeagueFi...
# 1133812955001294850  👀 Interesting choice of camera angle for the #...
# 1133822767059611648  El campo sin llenar, más aficionados neutrales...
# 1133835501499240448  When you find out Ozil was playing in this gam...
# 1133839843992190978  Congratulations to @ChelseaFC for bringing tha...
# 1133839952524001281  ⚽️ After scoring a brace in the #EuropaLeagueF...
# 1133841340578578432  Por fin el Madrid va a volver a fichar un galá...
# 1133841949620879360  🗣️ Hazard tardó poco en despejar su futuro tra...
# 1133934477544173568  What a night. A big thank you to all our suppo...
# 1134013194895314945  RT @mazi_duce: A Beautiful Morning to you all ...
# 1134136056922726402         16
# 1134136077231579136        338          Federal Capital Territory
# 1134136242214506496        217                South East, England
# 1134136445122285569          7                     Washington, DC
# 1134136566836862978        724                 Sagamu, Ogun-state
# 1134136883137732609        278                             london
# 1134136908143923201       3806                       Shaw, Oldham
# 1134136916020830208       1240                         Banyuwangi
#
# [1019 rows x 9 columns]

# %%
print(len(df))
dfFriends = df.drop_duplicates('userID')
len(dfFriends)
# Out:
# 1019
# 927

# %%
import csv

columns = ['userID', 'friendID']
dfEdges = pd.DataFrame()
dfFriends = df.drop_duplicates('userID')

f = open('friends.csv', 'w')
writer = csv.DictWriter(f, fieldnames=columns)    
writer.writeheader()

rows = []
    
for i in range(0,len(dfFriends)):
    try:
        p = dfFriends.iloc[i]
        next_cursor = -1

        while next_cursor != 0:
            resultFriends = twitter.get_friends_ids(user_id = p['userID'],
                                                   count = p['friends'],
                                                   cursor = next_cursor)

            next_cursor = resultFriends['next_cursor']
            for friend in resultFriends['ids']:
                friendData = {
                    'userID' : p['userID'],
                    'friendID' : friend,
                }
                rows.append(friendData)
                writer.writerow({'userID' : friendData['userID'], 'friendID': friendData['friendID']})
    except:
        print(datetime.datetime.now())
        time.sleep(60 * 15)
        continue

dfEdges = pd.DataFrame(rows, columns=columns)
dfEdges
# Out:
# ---------------------------------------------------------------------------
# TwythonRateLimitError                     Traceback (most recent call last)
# <ipython-input-19-3ca1aa3b86a7> in <module>
#      25                                                        count = p['friends'],
# ---> 26                                                        cursor = next_cursor)
#      27
#
# ~/anaconda3/lib/python3.7/site-packages/twython/endpoints.py in get_friends_ids(self, **params)
#     365         """
# --> 366         return self.get('friends/ids', params=params)
#     367     get_friends_ids.iter_mode = 'cursor'
#
# ~/anaconda3/lib/python3.7/site-packages/twython/api.py in get(self, endpoint, params, version)
#     269         """Shortcut for GET requests via :class:`request`"""
# --> 270         return self.request(endpoint, params=params, version=version)
#     271
#
# ~/anaconda3/lib/python3.7/site-packages/twython/api.py in request(self, endpoint, method, params, version)
#     263         content = self._request(url, method=method, params=params,
# --> 264                                 api_call=url)
#     265
#
# ~/anaconda3/lib/python3.7/site-packages/twython/api.py in _request(self, url, method, params, api_call)
#     198                 error_code=response.status_code,
# --> 199                 retry_after=response.headers.get('X-Rate-Limit-Reset'))
#     200         content = ''
#
# TwythonRateLimitError: Twitter API returned a 429 (Too Many Requests), Rate limit exceeded
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-3ca1aa3b86a7> in <module>
#      38         finished = True
#      39     except:
# ---> 40         time.sleep(60 * 15)
#      41         continue
#      42
#
# KeyboardInterrupt:

# %%
result = twitter.search(q='#EuropaLeagueFinal2019', count=100)
while (tweetCount < 1000):
    
    
    for tweet in result['statuses']:
        dictionaryColValue = {
            'tweetID' : tweet['id'],
            'text' : tweet['text'],
            'replyTo' : tweet['in_reply_to_user_id'],
            'retweeted' : tweet['retweet_count'],
            'tweetDate' : tweet['created_at'],
            'userID' : tweet['user']['id'],
            'userName' : tweet['user']['name'],
            'followers' : tweet['user']['followers_count'],
            'location' : tweet['user']['location']
        }
        rows.append(dictionaryColValue)
        tweetCount += 1
        
    last_id = rows[-1]['tweetID']
    #last_id = result['search_metadata']['max_id']
    result = twitter.search(q='#EuropaLeagueFinal2019', count=100, max_id = last_id)
